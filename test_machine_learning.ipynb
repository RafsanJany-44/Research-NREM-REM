# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/Research-NREM-REM/blob/main/test_machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data PreProcessing

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("https://raw.githubusercontent.com/RafsanJany-44/Research-NREM-REM/main/dataset/REM_NREM.csv")

# %%
data.head()
# Out:
#   Sleep_Stage  MeanP_Alpha_F4  MedianF_Alpha_F4  MeanF_Alpha_F4  \
# 0        NREM         0.00034          10.11512        17.85756
# 1        NREM         0.00035          10.73951        17.60780
# 2        NREM         0.00035           9.36585        17.60780
# 3        NREM         0.00050          10.36488        16.60878
# 4        NREM         0.00072           9.36585        15.98439
#
#    Spectral Edge_Alpha_F4  PeakF_Alpha_F4  MeanP_Beta_F4  MedianF_Beta_F4  \
# 0                17.48293        10.24000        0.00047         17.73268
# 1                17.10829         9.11610        0.00048         16.85854
# 2                16.98341         9.24098        0.00042         17.35805
# 3                15.85951         7.99220        0.00053         15.48488
# 4                15.48488         7.99220        0.00067         15.11024
#
#    MeanF_Beta_F4  Spectral Edge_Beta_F4  ...  MeanP_Delta_O2  \
# 0       25.35024               27.47317  ...         0.00112
# ...

# %%
dataframe=data
dataframe["Sleep_Stage"].unique()
# Out:
# array(['NREM', 'REM'], dtype=object)

# %% [markdown]
# Data encoding

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
dataframe["Sleep_Stage"]=encoder.fit_transform(dataframe["Sleep_Stage"])

# %%
dataframe.head()
# Out:
#    Sleep_Stage  MeanP_Alpha_F4  MedianF_Alpha_F4  MeanF_Alpha_F4  \
# 0            0         0.00034          10.11512        17.85756
# 1            0         0.00035          10.73951        17.60780
# 2            0         0.00035           9.36585        17.60780
# 3            0         0.00050          10.36488        16.60878
# 4            0         0.00072           9.36585        15.98439
#
#    Spectral Edge_Alpha_F4  PeakF_Alpha_F4  MeanP_Beta_F4  MedianF_Beta_F4  \
# 0                17.48293        10.24000        0.00047         17.73268
# 1                17.10829         9.11610        0.00048         16.85854
# 2                16.98341         9.24098        0.00042         17.35805
# 3                15.85951         7.99220        0.00053         15.48488
# 4                15.48488         7.99220        0.00067         15.11024
#
#    MeanF_Beta_F4  Spectral Edge_Beta_F4  ...  MeanP_Delta_O2  \
# 0       25.35024               27.47317  ...         0.00112
# ...

# %%
def sep_XY(dataset,target):
  x_col_name= list(dataset.iloc[:0,:])
  x_col_name.remove(target)
  return (dataset[x_col_name].values),(dataset[target].values)

# %%
X,y=sep_XY(dataframe,"Sleep_Stage")

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test= train_test_split(X,y, test_size=0.2,random_state=3)

# %%
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (71276, 75) (17820, 75) (71276,) (17820,)
